# %%
def table_multiply(n: int):
    """
    Print the multiplication table for a given number.
    """
    for i in range(1,13):
        print(f"{n} * {i} = {n * i}")

# %%
num=int(input("Enter a number of table"))

# %%
table_multiply(num)
