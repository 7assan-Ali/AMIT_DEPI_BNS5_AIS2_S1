# %% [markdown]
# ## Task 1 :Bank Account

# %%
class BankAccount:
    def __init__(self, balance):
            self.balance = balance
    
    def deposit_amount(self, amount):
        if amount <= 0:
                print("Amount must be positive")
                return
    
        self.balance += amount
        print(f"Deposited {amount}. New balance: {self.balance}")
            
    def withdraw_amount(self,amount):
        if amount<=0:
             print("Amount must be positive")
         
        if amount > self.balance:
            print("Insufficient funds")
            
        else:
            self.balance-=amount
            print(f"You Withdraw: {amount} , New Balance: {self.balance} ")
            
    def check_balance(self):
        print(f"Your Current Balance is: {self.balance}")

# %%
account=BankAccount(180)
account.deposit_amount(20)
account.withdraw_amount(30)
account.check_balance()
# Out:
# Deposited 20. New balance: 200
# You Withdraw: 30 , New Balance: 170
# Your Current Balance is: 170
