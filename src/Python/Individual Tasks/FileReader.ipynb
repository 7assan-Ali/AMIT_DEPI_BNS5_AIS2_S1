# %%
class TextFileReader:

    def __init__(self, file_path):
        self.file_path = file_path
        self.content = ""

    def read_file(self):
        try:
            with open(self.file_path, "r", encoding="utf-8") as file:
                self.content = file.read()

        except FileNotFoundError:
            print("File not found.")
            return

    def count_lines(self):
        return len(self.content.splitlines())

    def count_words(self):
        return len(self.content.split())

    def count_characters(self):
        return len(self.content)

    def display_content(self):
        print(self.content)

# %%
# Out:
# ========== File Content ==========
# Generative AI (GenAI) is a type of artificial intelligence that can create new content such as text, images, audio, video, and code.
#
# It works by learning from huge amounts of data and then generating new content based on the user’s prompt.
#
# GenAI is used in many areas, such as chatbots, coding, data analysis, content creation, translation, and image generation.
#
# In simple words: Traditional AI mainly analyzes or predicts, while Generative AI can create new content.
#
# ========== File Statistics ==========
# Number of Lines: 7
# Number of Words: 75
# Number of Characters: 470
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 18
#      16 print("Number of Words:", reader.count_words())
#      17 print("Number of Characters:", reader.count_characters())
# ---> 18 print(self.content)
#
# NameError: name 'self' is not defined

# %%
reader = TextFileReader(
    r"D:\DEPI\AMIT_DEPI_BNS5_AIS2_S1\src\Python\Individual Tasks\textfile.txt"
)

reader.read_file()

print("========== File Content ==========")
reader.display_content()

print("\n========== File Statistics ==========")
print("Number of Lines:", reader.count_lines())
print("Number of Words:", reader.count_words())
print("Number of Characters:", reader.count_characters())
# Out:
# ========== File Content ==========
# Generative AI (GenAI) is a type of artificial intelligence that can create new content such as text, images, audio, video, and code.
#
# It works by learning from huge amounts of data and then generating new content based on the user’s prompt.
#
# GenAI is used in many areas, such as chatbots, coding, data analysis, content creation, translation, and image generation.
#
# In simple words: Traditional AI mainly analyzes or predicts, while Generative AI can create new content.
#
# ========== File Statistics ==========
# Number of Lines: 7
# Number of Words: 75
# Number of Characters: 470
