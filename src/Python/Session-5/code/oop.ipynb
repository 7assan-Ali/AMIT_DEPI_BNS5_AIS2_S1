# %%
class StudentInfo:
    name = "Hassan"
    age = 21
    
    def std_inf(self):
       print(self)

# %%
s1 = StudentInfo()
s1.name = "Ali" 
s1.age = 22
print("Name:", s1.name)
print("Age:", s1.age)
print(s1)
s1.std_inf()


s1.std_inf()
# Out:
# Name: Ali
# Age: 22
# ...
# Name: Hassan
# Age: 21
# Name: Hassan
# Age: 21

# %% [markdown]
# ## self is a reference to the current instance of the class. It is used to access variables that belong to the class.

# %%
s1 = StudentInfo()
s2 = StudentInfo()
print(s1)
print(s2)

# %%
class Student:
    def __init__(self, name="Unknown", age=10)-> str:
         self.name = name
         self.age = age
    def student_info(self):
        print("Name:", self.name)
        print("Age:", self.age)

# %%
s1 = Student("Ali", 22)
s1.student_info()
# Out:
# Name: Ali
# Age: 22

# %%
print(dir(list))
list1=[1,2,3,4,5,6]
list1.clear()
# Out:
# ['__add__', '__class__', '__class_getitem__', '__contains__', '__delattr__', '__delitem__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__iadd__', '__imul__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__mul__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__reversed__', '__rmul__', '__setattr__', '__setitem__', '__sizeof__', '__str__', '__subclasshook__', 'append', 'clear', 'copy', 'count', 'extend', 'index', 'insert', 'pop', 'remove', 'reverse', 'sort']

# %% [markdown]
# ## Abstract

# %%
from abc import ABC,abstractmethod

class Animal(ABC):
    @abstractmethod
    def move(self):
        pass
class Bird(Animal):
    def move(self):
        print("move from bird")
        
class Cat(Animal):
    def move(self):
        print("move from cat")

# %%
a=Bird()
a.move()
# Out:
# move from bird

# %% [markdown]
# ## Encapsulation

# %%
class Employes:
    def __init__(self,name,salary):
        self.name=name
        self.salary=salary
        
    def set_salary(self,obj,new_salary):
        obj.salay=new_salary

# %%
class Manger:
    def __init__(self,name,salary):
        self.name=name
        self.salary=salary

# %%
E1=Employes("Hassan",15000)
M1=Manger("Ali",30000)
E1.set_salary(M1,60000)
print(M1.salary)
# Out:
# 30000

# %% [markdown]
# ## Inheritance

# %%
class A():
    def do_this(self):
        print("I'm in A")
        
class B(A):
    pass

class C():
    def do_this(self):
        print("I'm in C")     

class D(B,C):
    pass

x=D()
x.do_this()
# Out:
# I'm in A

# %%
class A():
    def do_this(self):
        print("I'm in A")
        
class B(A):
    pass

class C():
    def do_this(self):
        print("I'm in C")     

class D(C,B):
    pass

x=D()
x.do_this()
# Out:
# I'm in C

# %% [markdown]
# ## calc

# %%
class Calc:
    def __init__(self, x, y):
        self.x = x
        self.y = y

    def sum(self):
        return self.x + self.y

    def sub(self):
        return self.x - self.y

    def multi(self):
        return self.x * self.y

    def div(self):
        return self.x / self.y


if __name__ == "__main__":
    c = Calc(20, 5)

    print("Sum:", c.sum())
    print("Sub:", c.sub())
    print("Multiply:", c.multi())
    print("Divide:", c.div())
