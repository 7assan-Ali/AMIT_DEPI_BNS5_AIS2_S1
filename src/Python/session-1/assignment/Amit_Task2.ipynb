# %%
Encoded_message="###!!@mocleW EPGTQ!!!6789"
Encoded_message
# Out:
# '###!!@mocleW EPGTQ!!!6789'

# %%
start_postion=Encoded_message.index("m")
start_postion
# Out:
# 6

# %%
length_of_message=len(Encoded_message)
length_of_message
# Out:
# 25

# %%
end_postion=length_of_message-start_postion
end_postion
# Out:
# 19

# %%
core=Encoded_message[start_postion:end_postion-1]
core
# Out:
# 'mocleW EPGTQ'

# %%
space=core.find(" ")
space
# Out:
# 6

# %%
first_word = core[:space]
first_word
# Out:
# 'mocleW'

# %%
reserve_first_word=first_word[::-1]
reserve_first_word
# Out:
# 'Welcom'

# %%
second_word = core[space+1:]
second_word
# Out:
# 'EPGTQ'

# %%
e_character=second_word[0]
e_character
# Out:
# 'E'

# %%
second_word = second_word.replace("E", "")
second_word
# Out:
# 'PGTQ'

# %%
Welcome_message=(reserve_first_word+e_character).lower()
Welcome_message
# Out:
# 'welcome'

# %%
final_message=Welcome_message+" "+second_word
final_message
# Out:
# 'welcome PGTQ'
